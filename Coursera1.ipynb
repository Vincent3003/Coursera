# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Name: **Chi Dang** <br>
# My current or desired occupation: to become a Data Analyst or Data Scientist

# %% [markdown]
# *I am interested in data science because data plays a major role and is the at the heart of every organization. Without data, we would be unable to process, including big organization because they cannot establish baselines and create goals to keep moving forward. It will make every problem is unsolvable.*

# %% [markdown]
# ### This will randomize the number from 1 to 100

# %%
import random
c = random.randint(1, 100)
print(c)
# Out:
# 68

# %% [markdown]
# ### My favorite hobbies:

# %% [markdown]
# <ol>
#     <p>1. Listening to music.</p>
#     <p> - R&B </p>
#     <p> - Kpop </p>
#     <p>2. Watching movies.</p>
#     <p>3. Making candles.</p>
#     <p>4. Playing with my Britney Spaniel dog: </p>
#
# </ol>

# %% [markdown]
# ![image.jpeg](attachment:16d69501-0a89-4735-9db8-a18fc8eda3ab.jpeg)
